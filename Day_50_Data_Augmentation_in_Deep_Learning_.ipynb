# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxie503/CampusX-100Days-of-DL/blob/main/Day_50_Data_Augmentation_in_Deep_Learning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Dense

# %%
img = image.load_img('/content/Cimg.JPG', target_size=(200, 200))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
img = image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
datagen = ImageDataGenerator(
        rotation_range=30,
        shear_range=0.2,
        zoom_range=0.2,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='reflect')

# %%
input_batch = img.reshape(1,200,200,3)

# %%
i=0

for output in datagen.flow(input_batch, batch_size=1, save_to_dir='/content/Data Agument/',
                      save_prefix='aug', save_format='jpeg'):
    i = i + 1
    if i == 10:
        break
